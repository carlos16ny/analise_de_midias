# %%
import pandas as p
import os

# %%
os.listdir('.')
# Out:
# ['Ohio.xlsx',
#  'Illinois.xlsx',
#  '.DS_Store',
#  'NorthCarolina.xlsx',
#  'NewYork.xlsx',
#  'Michigan.xlsx',
#  'Indiana.xlsx',
#  'Washington.xlsx',
#  'California.xlsx',
#  'Pennsylvania.xlsx',
#  'Virginia.xlsx',
#  'Alabama.xlsx',
#  'Massachusetts.xlsx',
#  'Texas.xlsx',
#  'Georgia.xlsx',
#  'NewJersey.xlsx']

# %%
file = 'Alabama.xlsx'
reader = p.ExcelFile(file)

# %%
shets = reader.sheet_names

# %%
print shets
# Out:
# [u'data_Alabama']

# %%
data_frame = reader.parse('data_Alabama')

# %%
print data_frame
# Out:
#             Unnamed: 0 Unnamed: 1         Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                  NaN        NaN                NaN        NaN        NaN
# 1   Obesity Prevalence        NaN                NaN       2004        NaN
# 2                State  FIPS Code             County     Number    Percent
# 3              Alabama      01001     Autauga County      10180       30.2
# 4              Alabama      01003     Baldwin County      30120       25.7
# 5              Alabama      01005     Barbour County       6645       31.7
# 6              Alabama      01007        Bibb County       4605       29.3
# 7              Alabama      01009      Blount County      10330       25.5
# 8              Alabama      01011     Bullock County       2883       35.1
# 9              Alabama      01013      Butler County       4503         30
# 10             Alabama      01015     Calhoun County      23960       28.8
# ...

# %%
customers = pd.read_excel(file,sheetname=0,header=0,index_col=False,keep_default_na=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-3d20820146ce> in <module>()
# ----> 1 customers = pd.read_excel(  file,
#       2                             sheetname=0,
#       3                             header=0,
#       4                             index_col=False,
#       5                             keep_default_na=True
#
# NameError: name 'pd' is not defined

# %%
for col_name in data_frame[0]:
    print col_name
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-d5aa188e39ef> in <module>()
# ----> 1 for col_name in data_frame[0]:
#       2     print col_name
#
# /Users/carlosabreu/anaconda3/envs/py2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /Users/carlosabreu/anaconda3/envs/py2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
# ...
